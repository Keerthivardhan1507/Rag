# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Keerthi Vardhan",
        "date_created":"2026-06-15"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Keerthi Vardhan', 'date_created': '2026-06-15'}, page_content='this is the main text content I am using to create RAG')

# %%
## crete a simple txt file

import os
os.makedirs("../data/text_files",exist_ok = True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)
        
print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### Textloader

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

# %%
from langchain_community.document_loaders import DirectoryLoader

# %%
from langchain_community.document_loaders import DirectoryLoader
doc_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

doc = doc_loader.load()
doc
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
doc_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf",
    loader_cls = PyMuPDFLoader
)
doc = doc_loader.load()
doc
# Out:
# [Document(metadata={'producer': '', 'creator': 'WPS Docs', 'creationdate': '2026-06-14T10:13:35+05:30', 'source': '..\\data\\pdf\\Keerthi_Vardhan_Genpact_DataScientist.pdf', 'file_path': '..\\data\\pdf\\Keerthi_Vardhan_Genpact_DataScientist.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Un-named', 'subject': '', 'keywords': '', 'moddate': '2026-06-14T10:13:35+05:30', 'trapped': '', 'modDate': "D:20260614101335+05'30'", 'creationDate': "D:20260614101335+05'30'", 'page': 0}, page_content='KEERTHI VARDHAN NAIDU NETTEM\nGitHub | LinkedIn | nk.vardhannaidu@gmail.com | +91-9949902603\nPROFESSIONAL SUMMARY\nAspiring Data Scientist with hands-on experience in Artificial Intelligence, Machine Learning, Predictive Analytics, and\nAdvanced Analytics. Skilled in developing and deploying end-to-end AI/ML solutions, performing exploratory data analysis,\nand delivering actionable recommendations from complex datasets. Experienced in collaborating with cross-functional\nteams to understand data requirements and solve real-world business problems using data-driven approaches. Passionate\nabout staying up-to-date with the latest advancements in AI and data science.\nSKILLS\n•\nProgramming Languages & Databases: Python, SQL (MySQL), HTML, CSS, JavaScript\n•\nAI & ML: Artificial Intelligence (AI), Machine Learning, Advanced Analytics, Predictive Analytics, AutoML (TPOT/Auto-\nsklearn)\n•\nLibraries & Frameworks: NumPy, Pandas, Scikit-learn, XGBoost, SMOTE, Matplotlib, Seaborn\n•\nData Analysis: EDA, Feature Engineering, Data Cleaning, Data Wrangling, Data Preprocessing\n•\nData Visualization: Power BI, Excel, Matplotlib, Seaborn\n•\nModel Deployment: Flask, Streamlit\n•\nPerformance & Monitoring: System Performance Monitoring, Model Evaluation, Cross-Validation, Hyperparameter\nTuning\n•\nTools & IDEs: Git, GitHub, Jupyter Notebook, Google Colab, VS Code\n•\nMathematics: Probability & Statistics, Supervised & Unsupervised Learning\nINTERNSHIP EXPERIENCE\nData Science Intern | AI Variant\nMar 2025 – Jun 2025\n•\nDeveloped and implemented machine learning models and algorithms including classification and regression to solve\nreal-world business problems using Python (Pandas, NumPy, Scikit-learn).\n•\nCollected, cleaned, and preprocessed complex datasets for analysis; applied feature engineering and SMOTE-based\nclass balancing to improve model accuracy and robustness.\n•\nConducted exploratory data analysis (EDA) using Matplotlib and Seaborn; interpreted results to provide actionable\nrecommendations to cross-functional teams.\n•\nDeployed AI/ML models as production-ready web applications using Flask and Streamlit; monitored system\nperformance and model evaluation metrics including Accuracy, F1-score, and ROC-AUC.\n•\nApplied cross-validation, hyperparameter tuning, and advanced analytics techniques to continuously improve model\nmethodologies and prediction accuracy.\nPROJECTS\nCustomer Churn Prediction GitHub\nTech Stack: Python, Streamlit, Scikit-learn, Pandas, NumPy, SMOTE, Advanced Analytics\n•\nDeveloped an AI-powered ML model to predict telecom customer churn using 7,000+ records; applied advanced\nanalytics to extract meaningful insights and deliver actionable business recommendations.\n•\nPreprocessed complex datasets by handling missing values, encoding categorical features, scaling, and applying\nSMOTE to balance classes.\n•\nAchieved 97% accuracy and 86% F1-score; deployed via Streamlit for real-time prediction with system performance\nmonitoring using ROC-AUC, precision-recall, and confusion matrix.\nDiamond Price Prediction GitHub\nTech Stack: Python, Flask, Scikit-learn, Pandas, NumPy, Matplotlib, XGBoost, AutoML\n•\nBuilt an end-to-end AI/ML application predicting diamond prices; implemented Linear Regression, Random Forest,\nand XGBoost models with AutoML-inspired pipeline for automated model selection.'),
#  Document(metadata={'producer': '', 'creator': 'WPS Docs', 'creationdate': '2026-06-14T10:13:35+05:30', 'source': '..\\data\\pdf\\Keerthi_Vardhan_Genpact_DataScientist.pdf', 'file_path': '..\\data\\pdf\\Keerthi_Vardhan_Genpact_DataScientist.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Un-named', 'subject': '', 'keywords': '', 'moddate': '2026-06-14T10:13:35+05:30', 'trapped': '', 'modDate': "D:20260614101335+05'30'", 'creationDate': "D:20260614101335+05'30'", 'page': 1}, page_content='•\nPerformed EDA, feature engineering, hyperparameter tuning, and cross-validation; deployed via Flask with real-time\nprediction and performance monitoring.\nCrop Recommendation System GitHub\nTech Stack: Python, Flask, Scikit-learn, Pandas, NumPy, Machine Learning\n•\nDeveloped an ML-based crop recommendation system using soil and environmental parameters; collaborated across\ndata collection, analysis, and deployment phases.\n•\nImplemented Decision Tree, Random Forest, and Logistic Regression; interpreted results to provide actionable\nagricultural insights via Flask web app.\nStudent Performance Prediction GitHub\nTech Stack: Python, Flask, Scikit-learn, Pandas, NumPy, Predictive Analytics\n•\nBuilt a predictive analytics system analyzing demographics and academic factors; performed data ingestion,\ntransformation, and model training to select the best regression model.\n•\nAchieved R² score of 0.88; deployed via Flask with real-time prediction interface and system performance tracking.\nEDUCATION\n2021 – 2025\nB.Tech in ECE – Madanapalle Institute of Technology and Science\nCGPA: 7.99/10.0\nRelevant Coursework: Data Structures, DBMS, Computer Networks, Statistics, OOP\nCERTIFICATIONS\n•\nNPTEL – Introduction to Machine Learning\n•\nIBM – Python 101 for Data Science\n•\nTata Forage – GenAI Powered Data Analytics Job Simulation\n•\nGeeksforGeeks – Complete Machine Learning and Data Science Program')]

# %%
type(doc[0])
# Out:
# langchain_core.documents.base.Document
